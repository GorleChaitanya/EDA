# %%
1. Pandas      :  Data frame anaysis
2. Numpy       : Numerical analysis
3. matplotlib  : Graph and plots
4. Seaborn     : plots
4. Bokhe       : plots
5. Plotly      : plots

=====================Machine Learning ======================================

7. stats        : for statistical models
8. scikit-learn(sklearn)  : ML Models

================== Deep learning =========================================

9. OpenCV          : Computer vision
10. pillow         : Image operator
11. tensorflow     : Neural network creations (developed by google)
12. keras          : NN (Neural network)
13. pytorch        : alternative package of transfolw 
================= NLP ====================================================

14. NLTK           : Natural langauge toolkit
15. Spacy          :Alterantive to NLTK
16. wordcloud      : most frequnce

================= Scarapping =============================================

17. Sqlite         : Data base creation
18. Beautiful soup
19. Selenium

========================== API creations =================================

20. Flask
21. FastAPI
22. Gradio
23. Django

================================ UI App creation ========================

24. streamlit

======================= Transfer lerning models(DL)======================

25. Mobilnet
26. Resnet
27. VGGnet
28. Inception
29.  Yolo          : Ultralytics

==================== Transfer lerning models (NLP)====================

30. Word2vec
31. Glove

================= Huging Face Tranformers ==============================

32. BERT          : Bi Directional encoder representation of transformers

==================== Allen NLP ========================================
33. Allen NLP packages

========================GenAI========================================

34. Langchain
35. google GeminiAI related packages
36. OpenAI GPT realted packages
37. Amazon Bedrock related packages
38. Meta Llama related packages

===========================Images and video Generations =====================

39. GAN models related packages
40. SORA related 

======================= Model deployment (Mlops)============================

41. mlflow   using databricks
42. kubeflow   (GCP account)

====================== Cloud  application ==================================
43. Azure ML releated packages
44. GCP VertexAI releated packages 
45. AWS sagemakers related packages

===================== small ==============================================

46.time
47.logging
48.math
49. random
50. env
51. os
